# %%
# !pip install langchain langchain-experimental langchain-openai
# !pip install azure-keyvault-secrets
# !pip install azure-identity
# !pip install yfinance
# !pip install langchain-tavily
# !pip install langfuse
# Out:
# Requirement already satisfied: langchain in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (0.3.25)
# Requirement already satisfied: langchain-experimental in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (0.3.4)
# Requirement already satisfied: langchain-openai in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (0.3.18)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.58 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain) (0.3.63)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain) (0.3.43)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain) (2.11.5)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-core<1.0.0,>=0.3.58->langchain) (4.13.2)
# Requirement already satisfied: jsonpointer>=1.9 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.58->langchain) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: anyio in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: certifi in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: idna in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: greenlet>=1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.2)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-experimental) (0.3.24)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.12.4)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.9.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.4.0)
# Requirement already satisfied: numpy>=1.26.2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.20.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.1.0)
# Requirement already satisfied: openai<2.0.0,>=1.68.2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-openai) (1.82.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-openai) (0.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (0.10.0)
# Requirement already satisfied: sniffio in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from openai<2.0.0,>=1.68.2->langchain-openai) (4.67.1)
# Requirement already satisfied: regex>=2022.1.18 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: azure-keyvault-secrets in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (4.9.0)
# Requirement already satisfied: azure-core>=1.31.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from azure-keyvault-secrets) (1.34.0)
# Requirement already satisfied: isodate>=0.6.1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from azure-keyvault-secrets) (0.7.2)
# Requirement already satisfied: typing-extensions>=4.0.1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from azure-keyvault-secrets) (4.13.2)
# Requirement already satisfied: requests>=2.21.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from azure-core>=1.31.0->azure-keyvault-secrets) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from azure-core>=1.31.0->azure-keyvault-secrets) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-keyvault-secrets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-keyvault-secrets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-keyvault-secrets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-keyvault-secrets) (2025.4.26)
# Requirement already satisfied: azure-identity in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (1.23.0)
# Requirement already satisfied: azure-core>=1.31.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: cryptography>=2.5 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from azure-identity) (45.0.3)
# Requirement already satisfied: msal>=1.30.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from azure-identity) (1.32.3)
# Requirement already satisfied: msal-extensions>=1.2.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from azure-identity) (4.13.2)
# Requirement already satisfied: requests>=2.21.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from azure-core>=1.31.0->azure-identity) (2.32.3)
# Requirement already satisfied: six>=1.11.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from azure-core>=1.31.0->azure-identity) (1.17.0)
# Requirement already satisfied: cffi>=1.14 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: pycparser in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity) (2.22)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2025.4.26)
# Requirement already satisfied: yfinance in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (0.2.61)
# Requirement already satisfied: pandas>=1.3.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from yfinance) (2.2.6)
# Requirement already satisfied: requests>=2.31 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from yfinance) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from yfinance) (3.18.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from yfinance) (4.13.4)
# Requirement already satisfied: curl_cffi>=0.7 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from yfinance) (0.11.1)
# Requirement already satisfied: protobuf>=3.19.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from yfinance) (6.31.1)
# Requirement already satisfied: websockets>=13.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.13.2)
# Requirement already satisfied: cffi>=1.12.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: certifi>=2024.2.2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from curl_cffi>=0.7->yfinance) (2025.4.26)
# Requirement already satisfied: pycparser in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests>=2.31->yfinance) (2.4.0)
# Requirement already satisfied: langchain-tavily in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (0.2.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-tavily) (3.12.4)
# Requirement already satisfied: langchain<0.4.0,>=0.3.20 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-tavily) (0.3.25)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-tavily) (0.3.63)
# Requirement already satisfied: mypy<2.0.0,>=1.15.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-tavily) (1.16.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-tavily) (2.32.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.20.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain<0.4.0,>=0.3.20->langchain-tavily) (0.3.8)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain<0.4.0,>=0.3.20->langchain-tavily) (0.3.43)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain<0.4.0,>=0.3.20->langchain-tavily) (2.11.5)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain<0.4.0,>=0.3.20->langchain-tavily) (2.0.41)
# Requirement already satisfied: PyYAML>=5.3 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain<0.4.0,>=0.3.20->langchain-tavily) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-tavily) (9.1.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-tavily) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-tavily) (24.2)
# Requirement already satisfied: typing-extensions>=4.7 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain-tavily) (4.13.2)
# Requirement already satisfied: jsonpointer>=1.9 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain-tavily) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.20->langchain-tavily) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.20->langchain-tavily) (3.10.18)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.20->langchain-tavily) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.20->langchain-tavily) (0.23.0)
# Requirement already satisfied: anyio in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.20->langchain-tavily) (4.9.0)
# Requirement already satisfied: certifi in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.20->langchain-tavily) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.20->langchain-tavily) (1.0.9)
# Requirement already satisfied: idna in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.20->langchain-tavily) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.20->langchain-tavily) (0.16.0)
# Requirement already satisfied: mypy_extensions>=1.0.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from mypy<2.0.0,>=1.15.0->langchain-tavily) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from mypy<2.0.0,>=1.15.0->langchain-tavily) (0.12.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.20->langchain-tavily) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.20->langchain-tavily) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.20->langchain-tavily) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.3->langchain-tavily) (2.4.0)
# Requirement already satisfied: greenlet>=1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain<0.4.0,>=0.3.20->langchain-tavily) (3.2.2)
# Requirement already satisfied: sniffio>=1.1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain<0.4.0,>=0.3.20->langchain-tavily) (1.3.1)
# Requirement already satisfied: langfuse in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (2.60.7)
# Requirement already satisfied: anyio<5.0.0,>=4.4.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langfuse) (4.9.0)
# Requirement already satisfied: backoff>=1.10.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langfuse) (2.2.1)
# Requirement already satisfied: httpx<1.0,>=0.15.4 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langfuse) (0.28.1)
# Requirement already satisfied: idna<4.0,>=3.7 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langfuse) (3.10)
# Requirement already satisfied: packaging<25.0,>=23.2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langfuse) (24.2)
# Requirement already satisfied: pydantic<3.0,>=1.10.7 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langfuse) (2.11.5)
# Requirement already satisfied: requests<3,>=2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langfuse) (2.32.3)
# Requirement already satisfied: wrapt<2.0,>=1.14 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from langfuse) (1.17.2)
# Requirement already satisfied: sniffio>=1.1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from anyio<5.0.0,>=4.4.0->langfuse) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from anyio<5.0.0,>=4.4.0->langfuse) (4.13.2)
# Requirement already satisfied: certifi in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from httpx<1.0,>=0.15.4->langfuse) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from httpx<1.0,>=0.15.4->langfuse) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0,>=0.15.4->langfuse) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from pydantic<3.0,>=1.10.7->langfuse) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from pydantic<3.0,>=1.10.7->langfuse) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from pydantic<3.0,>=1.10.7->langfuse) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests<3,>=2->langfuse) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/user/Telco_clone/GAAPB01-training-code-base/Assignments/Assignment_1/.venv/lib/python3.12/site-packages (from requests<3,>=2->langfuse) (2.4.0)

# %%
from langchain_openai import AzureChatOpenAI
from azure.keyvault.secrets import SecretClient
from azure.identity import DefaultAzureCredential
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate
# from langchain_community.tools.yahoo_finance_news import YahooFinanceNewsTool
from langchain_tavily import TavilySearch
from langchain_core.output_parsers import JsonOutputParser
from pydantic import BaseModel, Field
import json, os
from langfuse.callback import CallbackHandler

# %%
KVUri = "https://dipanjans-kv.vault.azure.net"
credential = DefaultAzureCredential()
client = SecretClient(vault_url=KVUri, credential=credential)

# #### Setting up secrets for future use ####
# secretName_1 = "azure-openai-endpoint"
# secretValue_1 = 'https://dipanjan-oai.openai.azure.com/openai/deployments/gpt-4o-mini/chat/completions?api-version=2025-01-01-preview'

# secretName_2 = "azure-openai-key"
# secretValue_2 = 'E2EyDw7HealrkGoWMO3sbu9nCZ22rN8oWo3MTVzePBnPczmfihbYJQQJ99BEACYeBjFXJ3w3AAABACOGr5SL'

secretName_3 = "tavily-api-key"
secretValue_3 = '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'

secretName_4 = "langfuse-secret-key-1"
secretValue_4 = "sk-lf-e32025cf-21ff-4e4e-82ea-751e13f47ee8"


secretName_5 = "langfuse-public-key-1"
secretValue_5 = "pk-lf-0acc3b60-04c7-4e3f-b2b6-8a0b5f9e3632"

secretName_6 = "langfuse-host-1"
secretValue_6 = "http://localhost:3000"

client.set_secret(secretName_1, secretValue_1)
client.set_secret(secretName_2, secretValue_2)
client.set_secret(secretName_3, secretValue_3)
client.set_secret(secretName_4, secretValue_4)
client.set_secret(secretName_5, secretValue_5)
client.set_secret(secretName_6, secretValue_6)
